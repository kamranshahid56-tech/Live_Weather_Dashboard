# %% [markdown]
# <a href="https://colab.research.google.com/github/kamranshahid56-tech/Live_Weather_Dashboard/blob/main/Live_Weather_Dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import plotly.express as px
from google.colab import userdata

#configuration
API_KEY = userdata.get('API_KEY')
CITY = input("Enter City: ")
URL = f"https://api.openweathermap.org/data/2.5/forecast?q={CITY}&appid={API_KEY}&units=metric"
# Out:
# Enter City: Multan

# %%
# Fetch Data
response = requests.get(URL)
data = response.json()

# Check if the request was successful
if response.status_code == 200:
    forecast_list = []
    for entry in data['list']:
        forecast_list.append({
            "Time": entry['dt_txt'],
            "Temp": entry['main']['temp'],
            "Condition": entry['weather'][0]['main']
        })
    df = pd.DataFrame(forecast_list)
    print("Data successfully retrieved!")
else:
    print(f"Error {response.status_code}: {data.get('message', 'Unknown error')}")
# Out:
# Data successfully retrieved!

# %%
df = pd.DataFrame(forecast_list)
fig = px.line(df,
              x='Time',
              y='Temp',
              color='Condition', # This adds the condition to the legend and colors the data
              title=f"5-Day Temperature Forecast for {CITY}",
              labels={'Temp': 'Temperature (°C)', 'Time': 'Date/Time'},
              markers=True,
              hover_data={'Condition': True} # Ensures condition shows when you hover
             )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
